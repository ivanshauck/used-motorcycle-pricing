# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanshauck/used-motorcycle-pricing/blob/main/Untitled77.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import csv
import requests
from bs4 import BeautifulSoup
import time
from random import randint

# %%
cities1 = ['losangeles','sfbay','phoenix','seattle','sacramento']#1500


cities5 = ['fresno','bakersfield','santabarbara','stockton','wyoming','omaha','desmoines','wichita','oklahomacity','tulsa',
'littlerock','memphis','spacecoast','daytona','baltimore','richmond','akroncanton','albany','capecod','longisland','providence','syracuse']#100

# %%
cities2 = ['dallas','sandiego','chicago','portland','denver','boston','nh']#900
cities3 = ['newyork','austin','detroit','inlandempire']#600
cities4 = ['lasvegas','columbus','kansascity','tucson','reno','fortcollins','cosprings','jacksonville','pittsburgh','cincinnati',
           'milwaukee','maine']#300

# %%
list_of_cities = []

for city in cities1:
  page_number = 1
  while page_number <= 1500:
    city_link = 'https://' + str(city) + '.craigslist.org/search/mca?s=' + str(page_number)

    list_of_cities.append(city_link)
    page_number += 120

for city in cities5:
  page_number = 1
  while page_number <= 100:
    city_link = 'https://' + str(city) + '.craigslist.org/search/mca?s=' + str(page_number)
    list_of_cities.append(city_link)
    page_number += 100

# %%
list_of_cities = []
for city in cities2:
  page_number = 1
  while page_number <= 900:
    city_link = 'https://' + str(city) + '.craigslist.org/search/mca?s=' + str(page_number)
    list_of_cities.append(city_link)
    page_number += 120

for city in cities3:
  page_number = 1
  while page_number <= 600:
    city_link = 'https://' + str(city) + '.craigslist.org/search/mca?=' + str(page_number)
    list_of_cities.append(city_link)
    page_number += 120

for city in cities4:
  page_number = 1
  while page_number <= 250:
    city_link = 'https://' + str(city) + '.craigslist.org/search/mca?s=' + str(page_number)
    list_of_cities.append(city_link)
    page_number += 120

# %%
print(list_of_cities)
# Out:
# ['https://dallas.craigslist.org/search/mca?s=1', 'https://dallas.craigslist.org/search/mca?s=121', 'https://dallas.craigslist.org/search/mca?s=241', 'https://dallas.craigslist.org/search/mca?s=361', 'https://dallas.craigslist.org/search/mca?s=481', 'https://dallas.craigslist.org/search/mca?s=601', 'https://dallas.craigslist.org/search/mca?s=721', 'https://dallas.craigslist.org/search/mca?s=841', 'https://sandiego.craigslist.org/search/mca?s=1', 'https://sandiego.craigslist.org/search/mca?s=121', 'https://sandiego.craigslist.org/search/mca?s=241', 'https://sandiego.craigslist.org/search/mca?s=361', 'https://sandiego.craigslist.org/search/mca?s=481', 'https://sandiego.craigslist.org/search/mca?s=601', 'https://sandiego.craigslist.org/search/mca?s=721', 'https://sandiego.craigslist.org/search/mca?s=841', 'https://chicago.craigslist.org/search/mca?s=1', 'https://chicago.craigslist.org/search/mca?s=121', 'https://chicago.craigslist.org/search/mca?s=241', 'https://chicago.craigslist.org/se
# ...

# %%
len(list_of_cities)
# Out:
# 112

# %%
page_in_city = requests.get(city_link)
soup = BeautifulSoup(page_in_city.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="maine motorcycles/scooters - craigslist" property="og:title"/>
# <meta content="maine motorcycles/scooters - craigslist" name="description"/>
# <meta content="maine motorcycles/scooters - craigslist" property="og:description"/>
# <meta content="https://maine.craigslist.org/search/mca" property="og:url"/>
# <meta content="true" name="smartbanner:api"/>
# <meta content="the craigslist app" name="smartbanner:title"/>
# <meta content="what's old is new" name="smartbanner:author"/>
# <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
# <meta content="/images/app_icon.png" name="smartbanner:icon-google"/>
# <meta content="view" name="smartbanner:button"/>
# ...

# %%
items = soup.find_all('a', class_='result-image gallery')
items
print(len(items))
# Out:
# 118

# %%
for i in items:
  print((i.get('href')))
# Out:
# https://maine.craigslist.org/mcd/d/manchester-2022-beta-motorcycles-300-rx/7494927723.html
# https://maine.craigslist.org/mcy/d/brunswick-2008-suzuki-boulevard-m50/7494808038.html
# https://maine.craigslist.org/mcd/d/randolph-2015-harley-davidson-xl1200t/7494763157.html
# https://maine.craigslist.org/mcy/d/east-machias-yamaha-star-1100/7494734669.html
# https://maine.craigslist.org/mcy/d/shapleigh-2005-honda-vtx1300c/7494656083.html
# https://maine.craigslist.org/mcy/d/seabrook-harley-flhr-sreaming-eagle/7494650015.html
# https://maine.craigslist.org/mcy/d/norridgewock-2013-harley-davidson-road/7494649150.html
# https://maine.craigslist.org/mcy/d/norridgewock-2005-harley-davidson-road/7494648097.html
# https://maine.craigslist.org/mcy/d/norridgewock-2007-victory-jackpot/7494646095.html
# https://maine.craigslist.org/mcy/d/windham-1983-gpz-550-kawasaki/7494576821.html
# https://maine.craigslist.org/mcd/d/cape-coral-take-an-adventure-from/7494544976.html
# ...

# %%
links = []
mot_urls = 1
for single_page in list_of_cities:
  links_in_single_page = requests.get(single_page)
  soup = BeautifulSoup(links_in_single_page.content,'html.parser')

  try:
    posts = soup.find_all('a',class_='result-image gallery')
    
    for link in posts:
      l = link.get('href')
      links.append(l)
  except:
    pass

  if mot_urls % 5 == 0:
    city_link = l.strip()
    start = city_link.find('//') + len('//')
    end = city_link.find('.')
    city_string = city_link[start:end]
    print('Number of pages returned -->' + str(mot_urls) + '----' + city_string)

  time.sleep(randint(0,1))
  mot_urls += 1
# Out:
# Number of pages returned -->5----dallas
# Number of pages returned -->10----sandiego
# Number of pages returned -->15----sandiego
# Number of pages returned -->20----chicago
# Number of pages returned -->25----portland
# Number of pages returned -->30----portland
# Number of pages returned -->35----denver
# Number of pages returned -->40----denver
# Number of pages returned -->45----boston
# Number of pages returned -->50----nh
# Number of pages returned -->55----nh
# Number of pages returned -->60----newyork
# Number of pages returned -->65----austin
# Number of pages returned -->70----detroit
# Number of pages returned -->75----inlandempire
# Number of pages returned -->80----columbus
# Number of pages returned -->85----kansascity
# Number of pages returned -->90----reno
# Number of pages returned -->95----cosprings

# %%
len(links)

# %%
links

# %%
df = pd.DataFrame(links)
df.to_csv('./links.csv',sep=',',index=False)

# %%
pd.set_option('display.max_rows',None)
pd.options.display.max_colwidth = 100
links = pd.read_csv('./links.csv',names=['https'])
links = links['https'][1:]
print(len(links))


links
# Out:
# 13055
# 1           https://dallas.craigslist.org/ftw/mcy/d/naval-air-station-jrb-street-legal-dirt/7499799826.html
# 2           https://dallas.craigslist.org/dal/mcd/d/clearwater-2017-honda-cbr500r-financing/7499799256.html
# 3              https://dallas.craigslist.org/dal/mcd/d/clearwater-2015-kawasaki-ninja-zx-6r/7499798734.html
# 4                   https://dallas.craigslist.org/dal/mcd/d/clearwater-2021-harley-davidson/7499798050.html
# 5            https://dallas.craigslist.org/dal/mcd/d/clearwater-2016-campagna-rex-financing/7499797529.html
# 6              https://dallas.craigslist.org/dal/mcd/d/clearwater-2019-kawasaki-ninja-zx-6r/7499797136.html
# 7             https://dallas.craigslist.org/dal/mcd/d/clearwater-2020-bmw-s1000xr-financing/7499796895.html
# 8               https://dallas.craigslist.org/dal/mcy/d/flower-mound-2007-honda-interceptor/7499771022.html
# 9               https://dallas.craigslist.org/mdf/mcd/d/arlington-2022-suzuki-rm-450-single/7499760650.html
# ...

# %%
count = 0
motos = []

for link in links:
  each_page = requests.get(link)
  time.sleep(randint(1,2))
  page_soup = BeautifulSoup(each_page.content, 'html.parser')

  mot_details = []
  try:
    mot_details.append(page_soup.find('span',class_='price').text)

    for span in page_soup.find_all('span',recursive=True):
      if not span.attrs.values():
          mot_details.append(span.text)
    mot_details.append('date time: ' + page_soup.find('time', class_='date timeago').text.strip().replace(':',';'))
  
    city = link.strip()
    start = city.find('//') + len('//')
    end = city.find('.')
    substring = city[start:end]
    mot_details.append('city:'+substring)
 
    geos = page_soup.findAll('div', {'class':'mapbox'})
    lat = geos[0].contents[1].get('data-latitude')
    mot_details.append('lat:' + lat.strip())
    long = geos[0].contents[1].get('data-longitude')
    mot_details.append('long:' + long.strip())

    post_body = page_soup.find(attrs={'id' : 'postingbody'}).contents[2] 
    mot_details.append('post_body:' + re.sub('[^0-9a-zA-Z]+', '', post_body))
    mot_details.append('pID:' + link.strip().replace('html','').replace('.','').split('/')[-1])
  except:
    pass
  clean = []
  for string in mot_details:
    if string == mot_details[1]:
      clean.append('year make model: ' + string)
    if string == mot_details[0]:
      clean.append('price: ' + string.replace(',','').replace('$',''))
    else:
      clean.append(string)
  
  mot_final = []
  for s in clean:
    if ':' in s:
      mot_final.append(s)

  motos.append(mot_final)
  count += 1

  if count % 100 == 0: 
    print('loop # ->',count)
# Out:
# loop # -> 100
# loop # -> 200
# loop # -> 300
# loop # -> 400
# loop # -> 500
# loop # -> 600
# loop # -> 700
# loop # -> 800
# loop # -> 900
# loop # -> 1000
# loop # -> 1100
# loop # -> 1200
# loop # -> 1300
# loop # -> 1400
# loop # -> 1500
# loop # -> 1600
# loop # -> 1700
# loop # -> 1800
# loop # -> 1900
# loop # -> 2000
# loop # -> 2100
# loop # -> 2200
# loop # -> 2300
# loop # -> 2400
# loop # -> 2500
# loop # -> 2600
# loop # -> 2700
# loop # -> 2800
# loop # -> 2900
# loop # -> 3000
# loop # -> 3100
# loop # -> 3200
# loop # -> 3300
# loop # -> 3400
# loop # -> 3500
# loop # -> 3600
# loop # -> 3700
# loop # -> 3800
# loop # -> 3900
# loop # -> 4000
# loop # -> 4100
# loop # -> 4200
# loop # -> 4300
# loop # -> 4400
# loop # -> 4500
# loop # -> 4600
# loop # -> 4700
# loop # -> 4800
# loop # -> 4900
# loop # -> 5000
# loop # -> 5100
# loop # -> 5200
# loop # -> 5300
# loop # -> 5400
# loop # -> 5500
# loop # -> 5600
# loop # -> 5700
# loop # -> 5800
# loop # -> 5900
# ...

# %%
def list_to_dict(mylist):
  return dict(map(lambda s : map(str.strip, s.split(':')), mylist))

# %%
moto_dicts = []
for moto in motos:
  try:
    moto_dict = list_to_dict(moto)
    moto_dicts.append(moto_dict)
  except:
    pass

# %%
moto_dicts
# Out:
# [{'city': 'dallas',
#   'condition': 'like new',
#   'date time': '2022-06-22 12;20',
#   'engine displacement (CC)': '125',
#   'fuel': 'gas',
#   'lat': '32.768300',
#   'long': '-97.462200',
#   'odometer': '2000',
#   'paint color': 'black',
#   'price': '1600',
#   'title status': 'clean',
#   'transmission': 'manual',
#   'year make model': '2016 apollo 125cc'},
#  {'VIN': 'MLHPC4469H5400095',
#   'city': 'dallas',
#   'date time': '2022-06-22 12;19',
#   'lat': '27.894200',
#   'long': '-82.674600',
#   'odometer': '3091',
#   'paint color': 'red',
#   'price': '6990.00',
#   'title status': 'clean',
#   'year make model': '2017 Honda CBR500R'},
#  {'VIN': 'JKBZXJE14FA015927',
#   'city': 'dallas',
#   'date time': '2022-06-22 12;18',
#   'lat': '27.894200',
#   'long': '-82.674600',
#   'odometer': '1567',
#   'paint color': 'green',
#   'price': '8990.00',
#   'title status': 'clean',
#   'year make model': '2015 Kawasaki Ninja ZX-6R 30th Anniv'},
# ...

# %%
len(moto_dicts)
# Out:
# 9843

# %%
import pandas as pd
dfs = pd.DataFrame()
for item in moto_dicts:
  df = pd.DataFrame.from_dict(item,orient='index').transpose()
  dfs = pd.concat([dfs,df], axis=0, ignore_index=True, sort=True)

# %%
dfs.head()
# Out:
#                  VIN    city condition         date time  \
# 0                NaN  dallas  like new  2022-06-22 12;20
# 1  MLHPC4469H5400095  dallas       NaN  2022-06-22 12;19
# 2  JKBZXJE14FA015927  dallas       NaN  2022-06-22 12;18
# 3  1HD1LP313MB406291  dallas       NaN  2022-06-22 12;17
# 4  2C9T16S64G2145074  dallas       NaN  2022-06-22 12;16
#
#   engine displacement (CC) fuel        lat        long odometer paint color  \
# 0                      125  gas  32.768300  -97.462200     2000       black
# 1                      NaN  NaN  27.894200  -82.674600     3091         red
# 2                      NaN  NaN  27.894200  -82.674600     1567       green
# 3                      NaN  NaN  27.894200  -82.674600      211      custom
# 4                      NaN  NaN  27.894200  -82.674600     7291      orange
#
#       price title status transmission type  \
# 0      1600        clean       manual  NaN
# 1   6990.00        clean          NaN  NaN
# ...

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9537 entries, 0 to 9536
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   VIN                       2807 non-null   object
#  1   city                      9537 non-null   object
#  2   condition                 6149 non-null   object
#  3   date time                 9537 non-null   object
#  4   engine displacement (CC)  4274 non-null   object
#  5   fuel                      9442 non-null   object
#  6   lat                       9529 non-null   object
#  7   long                      9529 non-null   object
#  8   odometer                  9463 non-null   object
#  9   paint color               6584 non-null   object
#  10  price                     9537 non-null   object
#  11  title status              7585 non-null   object
#  12  transmission              9446 non-null   object
# ...

# %%
import json
dfs.to_json('moto_data4.json')
